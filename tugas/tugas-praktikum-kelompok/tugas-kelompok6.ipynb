# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
img = cv.imread('../../images/KTP.jpeg')
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
imgCensored = np.copy(img2)

# %%
# Menutup bagian pekerjaan
for y in range(194, 476):
    for x in range(327, 348):
        imgCensored[x, y] = [0, 0, 255]

# Menutup bagian kewarganegaraan
for y in range(194, 257):
    for x in range(350, 370):
        imgCensored[x, y] = [255, 0, 0]
plt.imshow(imgCensored)
